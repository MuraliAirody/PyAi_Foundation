# %% [markdown]
# # Project Description
#
# ### objective:
# ***customer transaction data from bank to uncover the behavioral insight. use only pandas for data manipulation and seaborn for visualization***

# %% [markdown]
# ### Domain Explanation
#
# ***you work as customer behavioral analyst ata a bank digital analytics department. Your manager has tasked you with finding the pattern in transaction behavioral like fraud detection, spending pattern and financial well being from the data collected from the thousand of customer transactions. Your report will help the bank design better financial products, detect the fraud faster and personalized offers.***

# %% [markdown]
# ##### Pandas -> processing
# ##### Seaborn -> Visual story telling

# %% [markdown]
# ## Column Explanations
# - **transaction_id**: Unique ID for each transaction
# - **customer_id**: ID mapping to individual customer
# - **account_id**: Bank account from which transaction is made
# - **transaction_date**: Date and time when transaction occurred
# - **posting_date**: Date when transaction was posted to the bank
# - **transaction_amount**: Amount debited or credited
# - **currency**: Currency of the transaction
# - **merchant_id**: Unique identifier for merchant
# - **merchant_name**: Name of the business or vendor
# - **merchant_category**: Type of goods/service purchased
# - **card_issuer**: Issuer bank of the transaction card
# - **location_city**: City where transaction took place
# - **location_state**: State of transaction
# - **location_country**: Country where merchant is located
# - **balance_before**: Account balance before transaction
# - **balance_after**: Account balance after transaction
# - **is_fraud**: Boolean indicator if the transaction was fraudulent
# - **customer_since**: Date the customer joined the bank
# - **customer_age**: Age of the customer
# - **customer_gender**: Gender identity of the customer
# - **credit_score**: Credit score of customer
# - **reward_points_earned**: Points earned from this transaction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
#load the data
data_file = "../Datasets/kaggle/customer_transaction_analysis_data.csv"

df = pd.read_csv(data_file)

# %%
df.head(5)
# Out:
#                          transaction_id                           customer_id  \
# 0  cfbfff6e-548d-45ab-bd47-c3af21b10774  ae101def-6378-4a57-af2f-13831eb933c6
# 1  db45f012-a0ee-4a80-a859-491371311b28  486c1800-f83b-4d99-bd8a-6e9747f2fe54
# 2  2fd4ea51-1374-4341-8890-1a6ecde181c0  3a7f6cca-57bc-4819-bfbe-398e8c133e1a
# 3  59a0d00e-c94b-42ff-9021-243b6642afed  81994b75-665c-4176-bd94-be1d93bc1c35
# 4  b1cd7143-605a-4081-8c14-96d0f6ff531c  ede611a7-9fa8-407f-adf5-911eb37987ac
#
#                              account_id          transaction_date  \
# 0  fced023a-c73b-4051-95ce-0044fee7d58b  2023-06-28T12:23:31.876Z
# 1  270f0001-fd5f-4fbf-86b1-39844c4d0ecf  2023-03-17T11:22:25.256Z
# 2  f6e89d11-a4e6-4677-b8b3-2dd16f5e2ac8  2022-10-15T07:40:35.636Z
# 3  addbbbc0-7c69-4c71-8114-da2cb5b6481b  2022-09-26T06:56:41.344Z
# 4  f8e3a1c2-4dad-477e-9bd3-46c31e4886be  2022-08-08T12:32:45.386Z
#
#                posting_date  transaction_amount currency  \
# 0  2022-03-11T10:53:37.841Z             4668.11      BMD
# 1  2023-12-07T18:52:16.361Z             1042.72      VES
# 2  2022-11-21T00:18:54.946Z             3428.38      DKK
# 3  2022-04-07T20:25:06.790Z             1539.85      AFN
# 4  2023-04-20T16:57:42.981Z             3146.31      UGX
#
#                             merchant_id        merchant_name  \
# 0  584b02d9-4e0c-4869-8038-7d9395199f66      Feeney and Sons
# 1  84beb445-2c1d-45b3-b2c2-8ff354e17686     Collier - Waters
# 2  c02b7600-f2c1-42e7-a935-dd9ce3eea4be  Rogahn - Cartwright
# 3  3cf64c65-289c-45aa-a4f6-3743fcaa95b1   Goodwin - Homenick
# 4  182755d6-2e60-48c7-8dd4-7425609a6ff3          McClure Inc
#
#   merchant_category  ... location_state location_country balance_before  \
# 0              Home  ...        Vermont            China     $9,162.74
# 1              Toys  ...        Alabama             Iran    6748.357564
# 2         Computers  ...     Washington          Senegal     3647.32929
# 3            Garden  ...       Nebraska            Macao    1435.559207
# 4            Health  ...        Georgia         Zimbabwe    4144.677691
#
#   balance_after is_fraud            customer_since  customer_age  \
# 0   4690.141442    False  2025-06-30T23:06:38.073Z            57
# 1    1941.71734    False  2024-09-03T10:16:15.469Z            23
# 2    5657.08509    False  2016-02-20T22:08:29.505Z            72
# 3   8541.294285    False  2018-01-31T00:21:14.114Z            53
# 4   8752.950082    False  2018-08-22T01:13:40.050Z            62
#
#                     customer_gender  credit_score reward_points_earned
# 0                       Androgynous           665                  145
# 1                  Transsexual male           735                  508
# 2  Male to female transgender woman           454                  526
# 3                           Agender           694                  748
# 4                           Cis man           345                  812
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   transaction_id        100000 non-null  object
#  1   customer_id           100000 non-null  object
#  2   account_id            100000 non-null  object
#  3   transaction_date      100000 non-null  object
#  4   posting_date          100000 non-null  object
#  5   transaction_amount    100000 non-null  float64
#  6   currency              100000 non-null  object
#  7   merchant_id           100000 non-null  object
#  8   merchant_name         100000 non-null  object
#  9   merchant_category     100000 non-null  object
#  10  card_issuer           100000 non-null  object
#  11  location_city         100000 non-null  object
#  12  location_state        100000 non-null  object
#  13  location_country      100000 non-null  object
#  14  balance_before        100000 non-null  object
#  15  balance_after         100000 non-null  object
#  16  is_fraud              100000 non-null  bool
#  17  customer_since        100000 non-null  object
#  18  customer_age          100000 non-null  int64
#  19  customer_gender       100000 non-null  object
#  20  credit_score          100000 non-null  int64
#  21  reward_points_earned  100000 non-null  int64
# dtypes: bool(1), float64(1), int64(3), object(17)
# memory usage: 16.1+ MB

# %% [markdown]
# #EDA
#
# - Check if all attributes are available or not described in Data Dictionary
# - Size of the data
# - Sanity Check
# - Type checking and Typecasting if required
# - Check for the missing values
# - Handling the misisng values
# - Check for duplicates
# - Handle the duplicates
# - Check for the outliers
# - Handle the outliers
# - Encoding (Converting the non-numeric to numeric)
# - Correlation
# - Analysis

# %% [markdown]
# - **Amount- Numeric but in data - object (Typecasting is required)**
# - **Transaction Date -> Date type - object (Typecasting is required)**

# %%
df.columns
# Out:
# Index(['transaction_id', 'customer_id', 'account_id', 'transaction_date',
#        'posting_date', 'transaction_amount', 'currency', 'merchant_id',
#        'merchant_name', 'merchant_category', 'card_issuer', 'location_city',
#        'location_state', 'location_country', 'balance_before', 'balance_after',
#        'is_fraud', 'customer_since', 'customer_age', 'customer_gender',
#        'credit_score', 'reward_points_earned'],
#       dtype='object')

# %%
#size of the data
df.shape
# Out:
# (100000, 22)

# %% [markdown]
#  ##### Sanity check
#  - Some irrelevant columns are present
#  - Some important columns are missing

# %%
df.iloc[:15,11:]
# Out:
#        location_city  location_state                  location_country  \
# 0    Fort Fannieland         Vermont                             China
# 1      Port Elsefurt         Alabama                              Iran
# 2         Maxinestad      Washington                           Senegal
# 3         Uriahfield        Nebraska                             Macao
# 4          South Fay         Georgia                          Zimbabwe
# 5         South Olen        Missouri                           Somalia
# 6       Eden Prairie           Idaho      Svalbard & Jan Mayen Islands
# 7       Rodrickworth         Florida               Trinidad and Tobago
# 8      Port Venastad         Indiana  Saint Vincent and the Grenadines
# 9          Nettieton        Missouri                            Mexico
# 10          Riceboro          Kansas                        Azerbaijan
# 11   Fort Arvelfield  South Carolina                           Lesotho
# 12         Boyleport            Utah                 Brunei Darussalam
# 13         Careyview        Colorado                            Greece
# 14  South Beulahside        New York                           Iceland
#
#    balance_before balance_after  is_fraud            customer_since  \
# 0      $9,162.74    4690.141442     False  2025-06-30T23:06:38.073Z
# 1     6748.357564    1941.71734     False  2024-09-03T10:16:15.469Z
# 2      3647.32929    5657.08509     False  2016-02-20T22:08:29.505Z
# 3     1435.559207   8541.294285     False  2018-01-31T00:21:14.114Z
# 4     4144.677691   8752.950082     False  2018-08-22T01:13:40.050Z
# 5      795.528597   6363.292379     False  2019-09-02T18:28:12.138Z
# 6     7455.518879   3401.828605     False  2018-09-04T02:33:44.655Z
# 7     8682.908873    9727.93909     False  2018-06-30T01:59:30.572Z
# 8     9611.483566   8550.299891     False  2022-11-17T08:32:07.267Z
# 9     6551.656791   7418.102938     False  2019-02-13T14:56:47.454Z
# 10    4114.420562   8534.516673     False  2020-12-04T15:05:26.765Z
# 11    7781.189634   1294.428316     False  2020-09-23T19:04:57.979Z
# 12     8538.98142   2248.523416     False  2016-01-16T22:46:39.152Z
# 13     8076.19493      $900.92      False  2021-07-21T05:08:15.149Z
# 14    8169.382369   8330.874583     False  2020-05-05T06:00:47.521Z
#
#     customer_age                   customer_gender  credit_score  \
# 0             57                       Androgynous           665
# 1             23                  Transsexual male           735
# 2             72  Male to female transgender woman           454
# 3             53                           Agender           694
# 4             62                           Cis man           345
# 5             70                     Cisgender man           826
# 6             82  Male to female transsexual woman           351
# 7             38                          Demi-boy           329
# 8             48          Female to male trans man           663
# 9             32  Male to female transgender woman           698
# 10            63                      Intersex man           323
# 11            32                          Cis male           411
# 12            73                    Male to female           796
# 13            58                          T* woman           741
# 14            55                          Demi-boy           629
#
#     reward_points_earned
# 0                    145
# 1                    508
# 2                    526
# 3                    748
# 4                    812
# 5                    880
# 6                    343
# 7                    359
# 8                    683
# 9                    815
# 10                   946
# 11                   829
# 12                   678
# 13                   860
# 14                   895

# %% [markdown]
# #### Type casting

# %%
df.dtypes
# Out:
# transaction_id           object
# customer_id              object
# account_id               object
# transaction_date         object
# posting_date             object
# transaction_amount      float64
# currency                 object
# merchant_id              object
# merchant_name            object
# merchant_category        object
# card_issuer              object
# location_city            object
# location_state           object
# location_country         object
# balance_before           object
# balance_after            object
# is_fraud                   bool
# customer_since           object
# customer_age              int64
# customer_gender          object
# credit_score              int64
# reward_points_earned      int64
# dtype: object

# %% [markdown]
# - transaction_date, posting_date customer_since-> Date
# - balnce_before and balance_after -> Numeric

# %%
columns_to_date = ["transaction_date", "posting_date", "customer_since"]

for col in columns_to_date:
    df[col] = pd.to_datetime(df[col])

df[columns_to_date].dtypes
# Out:
# transaction_date    datetime64[ns, UTC]
# posting_date        datetime64[ns, UTC]
# customer_since      datetime64[ns, UTC]
# dtype: object

# %%
df.dtypes
# Out:
# transaction_id                       object
# customer_id                          object
# account_id                           object
# transaction_date        datetime64[ns, UTC]
# posting_date            datetime64[ns, UTC]
# transaction_amount                  float64
# currency                             object
# merchant_id                          object
# merchant_name                        object
# merchant_category                    object
# card_issuer                          object
# location_city                        object
# location_state                       object
# location_country                     object
# balance_before                       object
# balance_after                        object
# is_fraud                               bool
# customer_since          datetime64[ns, UTC]
# customer_age                          int64
# customer_gender                      object
# credit_score                          int64
# reward_points_earned                  int64
# dtype: object

# %%
# balance_before and balance_after -> Numeric

def convert_numeric(col):
    df[col] = pd.to_numeric(df[col].replace(r'[^0-9.-]+','',regex=True),errors='coerce')

col_numeric = ['balance_before','balance_after']

for col in col_numeric:
    convert_numeric(col)    

df[col_numeric].dtypes
# Out:
# balance_before    float64
# balance_after     float64
# dtype: object

# %%
# example
dd=pd.DataFrame({'Amt':['4500', '$2500', '', '3,000', '-', '4564.4478', '.', '6000','`-700']})
dd.Amt=dd.Amt.replace(r'[^0-9.-]','',regex=True)

dd
# Out:
#          Amt
# 0       4500
# 1       2500
# 2
# 3       3000
# 4          -
# 5  4564.4478
# 6          .
# 7       6000
# 8       -700

# %%
pd.to_numeric(dd.Amt,errors="coerce")
# Out:
# 0    4500.0000
# 1    2500.0000
# 2          NaN
# 3    3000.0000
# 4          NaN
# 5    4564.4478
# 6          NaN
# 7    6000.0000
# 8    -700.0000
# Name: Amt, dtype: float64

# %%
#Handling missing values

df.isna().sum()
# Out:
# transaction_id          0
# customer_id             0
# account_id              0
# transaction_date        0
# posting_date            0
# transaction_amount      0
# currency                0
# merchant_id             0
# merchant_name           0
# merchant_category       0
# card_issuer             0
# location_city           0
# location_state          0
# location_country        0
# balance_before          3
# balance_after           0
# is_fraud                0
# customer_since          0
# customer_age            0
# customer_gender         0
# credit_score            0
# reward_points_earned    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# transaction_id          0
# customer_id             0
# account_id              0
# transaction_date        0
# posting_date            0
# transaction_amount      0
# currency                0
# merchant_id             0
# merchant_name           0
# merchant_category       0
# card_issuer             0
# location_city           0
# location_state          0
# location_country        0
# balance_before          0
# balance_after           0
# is_fraud                0
# customer_since          0
# customer_age            0
# customer_gender         0
# credit_score            0
# reward_points_earned    0
# dtype: int64

# %%
#check for duplicate

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#find the number of fraud transactions

df.is_fraud.value_counts()
# Out:
# is_fraud
# False    98993
# True      1004
# Name: count, dtype: int64

# %%
df.is_fraud.value_counts()*100/(len(df.is_fraud))
# Out:
# is_fraud
# False    98.99597
# True      1.00403
# Name: count, dtype: float64

# %%
sns.countplot(data=df,x='is_fraud')
# Out:
# <Axes: xlabel='is_fraud', ylabel='count'>

# %%
df.loc[df['is_fraud']==True].head()
# Out:
#                            transaction_id  \
# 246  04dbbaf4-3de0-4c44-b646-984a81f83e4f
# 368  62bdd690-257e-4d4b-8702-2ca5a26b0d06
# 594  b7b74493-aa9b-4909-9b27-6a05c272ea39
# 718  d31e422a-8486-481e-b079-deaca49d1182
# 767  e30474a2-99cd-4d5f-8e3a-93627c27de94
#
#                               customer_id  \
# 246  b6ddaedf-c638-4908-9d2e-a0433257a158
# 368  1e6f6765-7722-4c69-a49e-c00d60984796
# 594  5a2a6488-7460-42c9-985d-02db07ba0ca0
# 718  042d893f-3709-45d9-b71d-3d3f9794ba11
# 767  fd68683a-cbce-4860-af00-1fb2210abc2b
#
#                                account_id                 transaction_date  \
# 246  a3becb31-2b97-4ee6-af89-1f7e494d77e5 2022-10-12 01:55:47.667000+00:00
# 368  b9fb888d-46b6-48d2-ba31-358ce9956997 2023-05-18 13:45:52.523000+00:00
# 594  b32bdbdf-e129-41f6-9345-f818c1f30682 2022-09-07 10:51:48.439000+00:00
# 718  a6738f43-037c-4e90-a2ec-ce5d1317f2f1 2023-01-11 05:23:46.225000+00:00
# 767  97ca2f87-056c-4efa-9eda-2cfdf820dd50 2022-12-17 14:57:51.191000+00:00
#
#                         posting_date  transaction_amount currency  \
# 246 2022-01-12 22:02:07.608000+00:00               98.59      BTN
# 368 2022-04-29 08:50:25.553000+00:00             1797.57      KGS
# 594 2022-08-16 04:24:52.201000+00:00             2319.61      KHR
# 718 2023-06-03 14:42:54.926000+00:00             1021.44      SDG
# 767 2022-06-16 10:32:29.317000+00:00              660.36      EUR
#
#                               merchant_id             merchant_name  \
# 246  ab1bddbf-ee2f-481f-8347-fe03a92b8cd7           Leannon - Towne
# 368  6aa587e7-bdf6-4914-8ff4-57a4d0fa5fbe         Blanda - Mosciski
# 594  89fe7353-5d88-4350-9473-25dcc5f7c9bb          Altenwerth Group
# 718  3351fb6e-7a8a-430f-9947-b064382a008a            Ortiz - Jacobi
# 767  9f86e6a8-7530-430d-b257-08132e0ebc4d  Macejkovic - Stoltenberg
#
#     merchant_category  ...  location_state location_country balance_before  \
# 246            Sports  ...        Colorado          Mayotte    6654.550247
# 368              Home  ...        Virginia         Suriname    9178.256051
# 594             Shoes  ...  South Carolina           France    3088.647450
# 718           Grocery  ...            Iowa       Mauritania    3890.226281
# 767        Automotive  ...        New York          Eritrea     693.055046
#
#     balance_after  is_fraud                   customer_since  customer_age  \
# 246   3687.584740      True 2023-07-16 15:17:08.083000+00:00            22
# 368   2231.243502      True 2024-12-30 22:32:11.877000+00:00            44
# 594   9109.148639      True 2025-06-18 16:52:03.744000+00:00            37
# 718   7311.475451      True 2017-05-03 11:25:51.139000+00:00            47
# 767   1775.064178      True 2024-11-10 21:35:22.400000+00:00            34
#
#         customer_gender  credit_score reward_points_earned
# 246          Trans male           654                  423
# 368      Transmasculine           573                  344
# 594     Cisgender woman           695                  570
# 718          Omnigender           662                  431
# 767  Transsexual female           788                  683
#
# [5 rows x 22 columns]

# %%
#from transaction_date col create 2 new col year and month

df['transaction_month'] = df['transaction_date'].dt.month
df['transaction_year'] = df['transaction_date'].dt.year

# %%
df.columns
# Out:
# Index(['transaction_id', 'customer_id', 'account_id', 'transaction_date',
#        'posting_date', 'transaction_amount', 'currency', 'merchant_id',
#        'merchant_name', 'merchant_category', 'card_issuer', 'location_city',
#        'location_state', 'location_country', 'balance_before', 'balance_after',
#        'is_fraud', 'customer_since', 'customer_age', 'customer_gender',
#        'credit_score', 'reward_points_earned', 'transaction_month',
#        'transaction_year'],
#       dtype='object')

# %%
df[["transaction_month","transaction_year"]].head()
# Out:
#    transaction_month  transaction_year
# 0                  6              2023
# 1                  3              2023
# 2                 10              2022
# 3                  9              2022
# 4                  8              2022

# %%
#year by total fraud transaction

df.groupby(['transaction_year'])['is_fraud'].value_counts()
# Out:
# transaction_year  is_fraud
# 2022              False       49460
#                   True          522
# 2023              False       49533
#                   True          482
# Name: count, dtype: int64

# %%
df.groupby(['transaction_year'])['is_fraud'].value_counts()*100/len(df)
# Out:
# transaction_year  is_fraud
# 2022              False       49.461484
#                   True         0.522016
# 2023              False       49.534486
#                   True         0.482014
# Name: count, dtype: float64

# %%
df[df['is_fraud'] == 1].groupby('transaction_year').size().max()
# Out:
# np.int64(522)

# %%
#plot the graph

a = sns.countplot(data=df,x='transaction_year',hue='is_fraud')

for i in a.containers:
    a.bar_label(i)

plt.show()

# %%
#merchant with highest fraud transaction

df[df['is_fraud']==True].groupby(['merchant_id','merchant_name']).size().sort_values(ascending=False)
# Out:
# merchant_id                           merchant_name
# 001ece61-3563-4761-ac5d-6e8980520d7a  Toy Group                      1
# aecd8971-1283-484b-9a08-01a4a91861d5  Simonis, O'Reilly and Wyman    1
# aca57f09-b7fe-476f-ae3c-9b738f3842e7  Lemke and Sons                 1
# acf6fe72-1819-4011-81e4-cc205cbb22bf  Bogisich LLC                   1
# ad0e6f9c-3a11-4ecc-97f4-a37387a9ae91  Dibbert, Rohan and Koss        1
#                                                                     ..
# 5c05bcdd-32d8-4d40-857d-27c368f5c8a4  Reinger - Marks                1
# 5c13dbfe-2445-4d02-8707-ca4f8f792d17  Kemmer, Bins and Rowe          1
# 5c463ab9-f836-48b4-9f89-e886e56faa63  Wehner - Leffler               1
# 5c4ecc29-38cb-4e1c-839b-405d34863778  Swift - Quitzon                1
# ffe88ece-e438-4bc9-8260-e2a5414aff6a  Nader - Connelly               1
# Length: 1004, dtype: int64

# %%
df['merchant_category'].unique()
# Out:
# array(['Home', 'Toys', 'Computers', 'Garden', 'Health', 'Shoes', 'Kids',
#        'Music', 'Baby', 'Industrial', 'Electronics', 'Outdoors', 'Beauty',
#        'Movies', 'Jewelry', 'Tools', 'Sports', 'Books', 'Grocery',
#        'Games', 'Clothing', 'Automotive'], dtype=object)

# %%
df[df['is_fraud']==True].groupby(['merchant_category']).size().sort_values(ascending=False)
# Out:
# merchant_category
# Computers      56
# Movies         52
# Music          51
# Health         50
# Games          49
# Garden         49
# Jewelry        49
# Automotive     48
# Sports         48
# Kids           47
# Grocery        47
# Industrial     46
# Books          44
# Outdoors       43
# Toys           43
# Baby           43
# Clothing       43
# Beauty         43
# Home           40
# Electronics    39
# Tools          38
# Shoes          36
# dtype: int64

# %%
#top 3 merchant categories

df.groupby(['merchant_category']).size().sort_values(ascending=False).head(3)
# Out:
# merchant_category
# Jewelry        4670
# Home           4644
# Electronics    4640
# dtype: int64

# %%
df['merchant_category'].value_counts().nlargest(3)
# Out:
# merchant_category
# Jewelry        4670
# Home           4644
# Electronics    4640
# Name: count, dtype: int64

# %%
top3_merchant_category = df.groupby(['merchant_category']).size().nlargest(3)

# %%
plot = sns.barplot(x=top3_merchant_category.index,y=top3_merchant_category.values)

for i in plot.containers:
    plot.bar_label(i)

plt.show()

# %%
df[df['is_fraud']==True].groupby(['customer_gender']).size()
# Out:
# customer_gender
# Agender              17
# Androgyne            10
# Androgynous          10
# Bigender             17
# Cis                   9
#                      ..
# Two* person          15
# Two-spirit           17
# Two-spirit person    14
# Woman                 8
# Xenogender           11
# Length: 76, dtype: int64
