# %%
import matplotlib.pyplot as plt   # Import pyplot module for creating plots

# X-axis data:
# Represents the independent variable (for example, day numbers)
week_days = [1, 2, 3, 4, 5, 6, 7, 8]

# Y-axis data:
# Represents the dependent variable (temperature values corresponding to each day)
temp = [21, 34, 56, 34, 42, 56, 40, 25]

# plot() draws a line graph:
# - week_days is plotted on the X-axis
# - temp is plotted on the Y-axis
# The values are connected in order using straight line segments
plt.plot(week_days, temp)

# %%
# Plot temperature values against days
plt.plot(week_days, temp)

# Set label for the X-axis
# Describes what the values on the horizontal axis represent
plt.xlabel("Days")

# Set label for the Y-axis
# Describes what the values on the vertical axis represent
plt.ylabel("Temperature")

# Set the title of the graph
# Provides a short description of what the plot represents
plt.title("Weather Data")
# Out:
# Text(0.5, 1.0, 'Weather Data')

# %%
# Draw a line plot with customized color

# color="red" changes the line color to red
plt.plot(week_days, temp, color="red")

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather Data")
# Out:
# Text(0.5, 1.0, 'Weather Data')

# %%
# Draw a line plot with custom color and line style

# linestyle=":"   → draws a dotted line
# Supported line styles:
# '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
plt.plot(week_days, temp, color="red", linestyle=":")

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather Data")
# Out:
# Text(0.5, 1.0, 'Weather Data')

# %%
# Data for X-axis: represents days (independent variable)
week_days = [1, 2, 3, 4, 5, 6, 7, 8]

# Y-axis data: temperature values for each day
# Maximum temperature recorded per day
temp_max = [21, 34, 56, 34, 42, 56, 40, 25]

# Minimum temperature recorded per day
temp_min = [19, 28, 40, 28, 35, 30, 32, 18]

# Average temperature calculated per day
temp_avg = [24, 30, 34, 30, 37, 37, 36, 24]

# Plot maximum temperature line
# label is used by legend() to identify this line
plt.plot(week_days, temp_max, label="Max Temperature")

# Plot minimum temperature line
plt.plot(week_days, temp_min, label="Min Temperature")

# Plot average temperature line
plt.plot(week_days, temp_avg, label="Avg Temperature")

# Display the legend on the plot
# Automatically maps labels to corresponding lines
plt.legend()

# Label the X-axis
plt.xlabel("Days")

# Label the Y-axis
plt.ylabel("Temperature")

# Set the title of the graph
# Describes the overall purpose of the visualization
plt.title("Daily Weather Temperature Comparison")
# Out:
# Text(0.5, 1.0, 'Weather Data')

# %%
# Bar Plot
# One column is categorical (Company names)
# The other column is numerical (Revenue values)

import matplotlib.pyplot as plt

# Categorical data for X-axis
# Each value represents a company
company = ["Amazon", "Google", "Tcs", "Wipro"]

# Numerical data for Y-axis
# Represents revenue corresponding to each company
revenue = [90, 60, 80, 100]

# Create a bar chart
# company → categories on X-axis
# revenue → height of each bar
# label   → used to display legend information
plt.bar(company, revenue, label="Revenue")

# Display legend on the plot
plt.legend()

# Label the X-axis to describe categories
plt.xlabel("Company")

# Label the Y-axis to describe values
plt.ylabel("Revenue")

# Set the title of the plot
# Explains what the bar chart represents
plt.title("Company Revenue Data")
# Out:
# Text(0.5, 1.0, 'Company Revenue Data')

# %%
# Histogram
# X-axis → data values (blood sugar levels)
# Y-axis → frequency (count of values in each bin)


# Blood sugar readings (numerical data)
blood_sugar = [80, 75, 90, 134, 89, 145, 160]

# ----------------------------------------------------
# Default histogram
# By default, matplotlib automatically chooses the number of bins
# Each bin represents a range of values
# ----------------------------------------------------
plt.hist(blood_sugar)
# Out:
# (array([2., 2., 0., 0., 0., 0., 1., 0., 1., 1.]),
#  array([ 75. ,  83.5,  92. , 100.5, 109. , 117.5, 126. , 134.5, 143. ,
#         151.5, 160. ]),
#  <BarContainer object of 10 artists>)

# %%
# ----------------------------------------------------
# Histogram with custom bins
# bins define the value ranges:
# 75–100, 100–125, 125–150, 150–200
# Values are counted based on which range they fall into
# ----------------------------------------------------
plt.hist(blood_sugar, bins=[75, 100, 125, 150, 200])

# Label the X-axis
plt.xlabel("Blood Sugar Level")

# Label the Y-axis
plt.ylabel("Frequency")

# Add a title to describe the histogram
plt.title("Blood Sugar Level Distribution")
# Out:
# Text(0.5, 1.0, 'Blood Sugar Level Distribution')

# %%
# ----------------------------------------------------
# Pie Chart – Basic Example
# ----------------------------------------------------
# exp_value → numerical values (expenses)
# exp_cat   → categorical labels for each expense
exp_value = [1200, 3000, 3500, 600]
exp_cat = ["rent", "food", "bill", "others"]

# Create a simple pie chart
# labels → names for each slice
plt.pie(exp_value, labels=exp_cat)
# Out:
# ([<matplotlib.patches.Wedge at 0x7e87b4bb11c0>,
# ...
#  [Text(0.9884705644828431, 0.48262401841492464, 'rent'),
#   Text(-0.501243686436798, 0.9791602355116599, 'food'),
#   Text(-0.22734486138642432, -1.0762501168414282, 'bill'),
#   Text(1.0717551386984592, -0.2476709968354124, 'others')])

# %%
exp_value=[1200,3000,3500,600]
exp_cat=["rent","food","bill","others"]

# ----------------------------------------------------
# Pie Chart with Percentage Display
# ----------------------------------------------------
# autopct formats and displays percentage values on each slice
# "%0.2f%%" → shows percentage with 2 decimal places
plt.pie(exp_value, labels=exp_cat, autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7e87b18f5cd0>,
# ...
#  [Text(0.9884705644828431, 0.48262401841492464, 'rent'),
#   Text(-0.501243686436798, 0.9791602355116599, 'food'),
#   Text(-0.22734486138642432, -1.0762501168414282, 'bill'),
#   Text(1.0717551386984592, -0.2476709968354124, 'others')],
#  [Text(0.5391657624451871, 0.26324946458995885, '14.46%'),
#   Text(-0.2734056471473443, 0.534087401188178, '36.14%'),
#   Text(-0.1240062880289587, -0.5870455182771426, '42.17%'),
#   Text(0.5845937120173412, -0.13509327100113402, '7.23%')])

# %%
# ----------------------------------------------------
# Pie Chart with Exploded Slice
# ----------------------------------------------------
# explode moves a slice outward for emphasis
# Here, the second slice ("travel") is highlighted
exp_value = [12000, 2500, 3000, 3500, 600]
exp_cat = ["rent", "travel", "food", "bill", "others"]

plt.pie(
    exp_value,
    labels=exp_cat,
    autopct="%0.2f%%",
    explode=[0, 0.1, 0, 0, 0]  # Only "travel" slice is exploded
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7e8798164f20>,
# ...
#  [Text(-0.191013134139045, 1.0832885038559115, 'rent'),
#   Text(-0.9079373460982529, -0.7846335294645912, 'travel'),
#   Text(-0.06395911139430453, -1.0981389857707682, 'food'),
#   Text(0.8528432033269512, -0.6947362596978978, 'bill'),
#   Text(1.095814186335551, -0.09587110631339567, 'others')],
#  [Text(-0.10418898225766089, 0.5908846384668608, '55.56%'),
#   Text(-0.5296301185573141, -0.4577028921876781, '11.57%'),
#   Text(-0.03488678803325702, -0.5989849013295098, '13.89%'),
#   Text(0.4651872018147006, -0.37894705074430785, '16.20%'),
#   Text(0.5977168289103004, -0.05229333071639763, '2.78%')])

# %%
x=[1,2,3,4,5,6,7]
y=[12,3,45,67,11,10,90]

plt.scatter(x,y)

# %%
exp_value=[12000,2500,3000,3500,600]
exp_cat=["rent","travel","food","bill","others"]

plt.pie(exp_value,labels=exp_cat,autopct="%0.2f%%",explode=[0,0.1,0,0,0])
# ----------------------------------------------------
# Pie Chart with Title and File Output
# ----------------------------------------------------
# Title gives context to the visualization
plt.title("Expense")

# Save the pie chart as an image file
# This is required in GitHub Codespaces to view the plot
plt.savefig("exp_pie.png")
